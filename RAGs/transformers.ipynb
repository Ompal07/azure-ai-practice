# %%
# %pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\ompal\anaconda3\lib\site-packages (2.7.1)
# Requirement already satisfied: filelock in c:\users\ompal\anaconda3\lib\site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\ompal\anaconda3\lib\site-packages (from torch) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\ompal\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\ompal\anaconda3\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\ompal\anaconda3\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\ompal\anaconda3\lib\site-packages (from torch) (2023.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ompal\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ompal\anaconda3\lib\site-packages (from jinja2->torch) (2.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import pipeline
qa = pipeline("question-answering", model="distilbert-base-cased-distilled-squad")
# Out:
# All PyTorch model weights were used when initializing TFDistilBertForQuestionAnswering.
#
# All the weights of TFDistilBertForQuestionAnswering were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForQuestionAnswering for predictions without further training.

# %%
result = qa(question="When is Opus 2 known for?", context="Opus 2 builds legal collaboration software with AI features.")
print(result)
# Out:
# {'score': 0.38545912504196167, 'start': 7, 'end': 59, 'answer': 'builds legal collaboration software with AI features'}

# %%
classifier = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# All PyTorch model weights were used when initializing TFDistilBertForSequenceClassification.
#
# All the weights of TFDistilBertForSequenceClassification were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.

# %%
print(classifier(''' 
                 "It was incredibly humbling when I found out that the foundation wanted to create a memorial in his honour and I was absolutely staggered by the response that the fundraiser had from the public," said Mr Wardell.

"It goes to show how many people were touched by Finn's story."

When his attacker was only charged with criminal damage, Mr Wardell campaigned for Finn's Law, calling for legal protection for service animals.

The legislation was passed in 2019, as the Animal Welfare (Service Animals) Bill

Finn recovered from his injuries and continued working briefly, before he retired.

He died in 2023 at the age of 14 and the memorial was unveiled on the second anniversary of his death.
                 '''))
# Out:
# [{'label': 'POSITIVE', 'score': 0.8960081338882446}]
