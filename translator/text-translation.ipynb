# %%
# %pip install azure-ai-translation-text==1.0.0b1
# Out:
# Requirement already satisfied: azure-ai-translation-text==1.0.0b1 in c:\users\ompal\anaconda3\lib\site-packages (1.0.0b1)
# Requirement already satisfied: msrest>=0.7.1 in c:\users\ompal\anaconda3\lib\site-packages (from azure-ai-translation-text==1.0.0b1) (0.7.1)
# Requirement already satisfied: azure-core<2.0.0,>=1.24.0 in c:\users\ompal\anaconda3\lib\site-packages (from azure-ai-translation-text==1.0.0b1) (1.35.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\ompal\anaconda3\lib\site-packages (from azure-ai-translation-text==1.0.0b1) (4.14.1)
# Requirement already satisfied: requests>=2.21.0 in c:\users\ompal\anaconda3\lib\site-packages (from azure-core<2.0.0,>=1.24.0->azure-ai-translation-text==1.0.0b1) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\ompal\anaconda3\lib\site-packages (from azure-core<2.0.0,>=1.24.0->azure-ai-translation-text==1.0.0b1) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ompal\anaconda3\lib\site-packages (from msrest>=0.7.1->azure-ai-translation-text==1.0.0b1) (2023.7.22)
# Requirement already satisfied: isodate>=0.6.0 in c:\users\ompal\anaconda3\lib\site-packages (from msrest>=0.7.1->azure-ai-translation-text==1.0.0b1) (0.7.2)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\users\ompal\anaconda3\lib\site-packages (from msrest>=0.7.1->azure-ai-translation-text==1.0.0b1) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ompal\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.24.0->azure-ai-translation-text==1.0.0b1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ompal\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.24.0->azure-ai-translation-text==1.0.0b1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ompal\anaconda3\lib\site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.24.0->azure-ai-translation-text==1.0.0b1) (1.26.16)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ompal\anaconda3\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.7.1->azure-ai-translation-text==1.0.0b1) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from azure.core.credentials import AzureKeyCredential
from azure.ai.translation.text import TextTranslationClient
import os

# %%
from azure.ai.translation.text import TextTranslationClient, TranslatorCredential
from azure.ai.translation.text.models import InputTextItem
from azure.core.exceptions import HttpResponseError
from dotenv import load_dotenv
import os

load_dotenv()  # Load variables from .env file

key = os.getenv("AZURE_TRANSLATOR_KEY")
endpoint = os.getenv("ENDPOINT")
region = os.getenv("REGION")


credential = TranslatorCredential(key, region)
text_translator = TextTranslationClient(endpoint=endpoint, credential=credential)

# %%
try:
    source_language = "en"
    target_languages = ["es", "ja"]
    input_text_elements = [ InputTextItem(text = "This is the sample translation from English Language to Spanish and Italian through the same api call") ]

    response = text_translator.translate(content = input_text_elements, to = target_languages, from_parameter = source_language)
    translation = response[0] if response else None

    if translation:
        for translated_text in translation.translations:
            print(f"Text was translated to: '{translated_text.to}' and the result is: '{translated_text.text}'.")

except HttpResponseError as exception:
    print(f"Error Code: {exception.error.code}")
    print(f"Message: {exception.error.message}")
# Out:
# Text was translated to: 'es' and the result is: 'Este es el ejemplo de traducción del idioma inglés al español e italiano a través de la misma llamada a la API'.
# Text was translated to: 'ja' and the result is: 'これは、同じ API 呼び出しによる英語からスペイン語およびイタリア語への翻訳のサンプルです'.
